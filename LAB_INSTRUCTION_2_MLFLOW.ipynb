# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration
#
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.
#
# You have two options for running MLflow:
#
# #### Option 1: Local MLflow (Simple)
# 1. Open terminal - we recommend to split it into 2 shells or just open additional session.
#
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5001
# ```
#
#
# **Important: Keep this terminal window open.** The MLflow server will continue running and be accessible at http://localhost:5001
#
# #### Option 2: MLflow with Docker (Recommended for production-like setup)
#
# 1. Create a `docker-compose.yml` file:
# ```yaml
# services:
#   mlflow:
#     image: ghcr.io/mlflow/mlflow:v2.9.2
#     container_name: mlflow-server
#     ports:
#       - "5001:5000"
#     volumes:
#       - ./mlflow-data:/mlflow
#     command:
#       - mlflow
#       - server
#       - --backend-store-uri
#       - sqlite:////mlflow/mlflow.db
#       - --default-artifact-root
#       - /mlflow/artifacts
#       - --host
#       - 0.0.0.0
#       - --port
#       - "5000"
#     restart: unless-stopped
# ```
#
# 2. Start MLflow with Docker:
# ```bash
# docker compose down -v
# rm -rf mlflow-data
# mkdir -p mlflow-data/artifacts
# docker compose up -d
# ```
#
# 3. Check if it's running:
# ```bash
# docker-compose ps
# ```
#
# 4. View logs (optional):
# ```bash
# docker-compose logs -f mlflow
# ```
#
# 5. To stop the server later:
# ```bash
# docker-compose down
# ```
#
# **Important: Add MLflow files to .gitignore**
#
# MLflow creates local files that should not be committed to Git. Add these lines to your `.gitignore`:
#
# ```
# # MLflow
# mlflow.db
# mlflow-artifacts/
# mlruns/
# ```
#
# These files contain experiment data and artifacts that are specific to your local machine. In production, you would use a remote tracking server and artifact storage (like S3).

# %% [markdown]
# ### Connecting to MLflow
#
# To verify if the server runs properly, let's connect to it:
#
# ```python
# import mlflow
# import mlflow.sklearn
#
# import warnings
#
# warnings.filterwarnings("ignore")
#
# mlflow.set_tracking_uri("http://localhost:5001")
# print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# ```
#
# **To stop the MLflow server later:**
#
# - **Local setup**: Press `Ctrl+C` in the terminal where it's running
# - **Docker setup**: Run `docker-compose down`
#
# The server will shut down gracefully and save all your experiments.
#
# **Note:** Keep the server running throughout this lab session. All your experiments will be logged to this server instance.

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5001")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5001

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

# As we have temporal data, the best way to evaluate our model is time (chronological) 
# split, where the newest data is used for testing. We will assume that we have the 
# data #for years 2006 and 2007, and evaluate using data from 2008.

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a bunch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2026/04/11 15:10:40 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# <Experiment: artifact_location='/mlflow/artifacts/1', creation_time=1773573097422, experiment_id='1', last_update_time=1775911508205, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:5001/#/experiments/1/runs/a1807af6f43546a5a75d57a9367a6f3d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 🏃 View run Decision Tree at: http://localhost:5001/#/experiments/1/runs/c4808b79d85a4d22a0c73581f8d22177
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:10:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:52 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:5001/#/experiments/1/runs/1f554797456944e596869972e6c194cd
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:10:53 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:54 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:56 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:57 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:58 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:10:59 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:10:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:5001/#/experiments/1/runs/c749a3dc737544e8afb7327e754302e0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:11:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:11:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:11:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:11:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:11:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:11:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:11:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:11:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:11:02 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:11:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:11:02 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5001/#/experiments/1/runs/510ceb9a2064404db2c82e304ba6960f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ## 2.3 Connecting DVC and MLflow
#
# You've already used DVC to version your dataset in the first part of this lab. Now let's connect DVC metadata with MLflow experiments to create a complete audit trail. When you run experiments, you want to know:
# - Which version of the data was used?
# - Can I reproduce these exact results?
# - What changed between experiments?
#
# By logging DVC metadata in MLflow, you create a link between your data versions and experiment results.

# %% [markdown]
# ### Reading DVC metadata
#
# DVC stores metadata in `.dvc` files. Let's read it:

# %%
import yaml

def get_dvc_metadata(dvc_file_path):
    with open(dvc_file_path, 'r') as f:
        dvc_data = yaml.safe_load(f)
    
    metadata = {
        'md5': dvc_data['outs'][0]['md5'],
        'size': dvc_data['outs'][0]['size'],
        'path': dvc_data['outs'][0]['path']
    }
    return metadata

dvc_metadata = get_dvc_metadata('data/ames_data_2006_2008.parquet.dvc')
print("DVC Metadata:")
print(f"MD5 hash: {dvc_metadata['md5']}")
print(f"File size: {dvc_metadata['size']} bytes")
print(f"Data path: {dvc_metadata['path']}")
# Out:
# DVC Metadata:
# MD5 hash: f44053333f88a0646819936b37f000ee
# File size: 162560 bytes
# Data path: ames_data_2006_2008.parquet

# %% [markdown]
# ### Exercise 1 - Logging DVC metadata in MLflow
#
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Now let's modify our training to include DVC metadata. This creates a complete audit trail:
# - **Git commit** → tracks code version
# - **DVC hash** → tracks data version
# - **MLflow run** → tracks experiment results
#
# Your task is to:
# 1. Run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again.
# 2. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
# 3. Make sure you have included DVC metadata logging. You can initialize dvc_metadata by calling above defined `get_dvc_metadata` function with the .dvc metadata file. Then you can just for each experiment add param logging like:
#
# ```python
# mlflow.log_param("param_name", "value you want to log") # e.g md5
# ```

# %%
from sklearn.svm import SVR   
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor                                                                                                          
from sklearn.preprocessing import PolynomialFeatures                                                                                                                         
from sklearn.pipeline import Pipeline as SKPipeline

def fit_sklearn_models_with_cv_and_dvc(models, X_train, X_test, y_train, y_test, dvc_metadata):                                                                              
    results = {}                                                                                                                                                             
                                                                                                                                                                            
    for model_name, model in models:                                                                                                                                         
        with mlflow.start_run(run_name=model_name):                                                                                                                          
            # Log DVC metadata for data versioning                                                                                                                           
            mlflow.log_param("data_dvc_md5", dvc_metadata['md5'])                                                                                                            
            mlflow.log_param("data_dvc_size", dvc_metadata['size'])                                                                                                          
            mlflow.log_param("data_path", dvc_metadata['path'])                                                                                                              
                                                                                                                                                                            
            model.fit(X_train, y_train)                                                                                                                                      
            y_pred = model.predict(X_test)                                                                                                                                   
                                                                                                                                                                            
            rmse = root_mean_squared_error(y_test, y_pred)                                                                                                                   
            mae = mean_absolute_error(y_test, y_pred)                                                                                                                        
            r2 = r2_score(y_test, y_pred)                                                                                                                                    
                                                                                                                                                                            
            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")                                                                                         
            cv_mean = cv_scores.mean()                                                                                                                                       
            cv_std = cv_scores.std()                                                                                                                                         
                                                                                                                                                                            
            # Log additional custom metrics                                                                                                                                  
            mlflow.log_metric("cv_r2_mean", cv_mean)                                                                                                                         
            mlflow.log_metric("cv_r2_std", cv_std)                                                                                                                           
                                                                                                                                                                            
            results[model_name] = {                                                                                                                                          
                "rmse": rmse,                                                                                                                                                
                "mae": mae,                                                                                                                                                  
                "r2": r2,                                                                                                                                                    
                "cv_r2_mean": cv_mean,                                                                                                                                       
            }                                                                                                                                                                
                                                                                                                                                                            
            print(f"\n{model_name}:")                                                                                                                                        
            print(f"  RMSE: {rmse:.2f}")                                                                                                                                     
            print(f"  MAE: {mae:.2f}")                                                                                                                                       
            print(f"  R^2: {r2:.3f}")                                                                                                                                        
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")                                                                                                    
            print(f"  DVC MD5: {dvc_metadata['md5']}")                                                                                                                       
                                                                                                                                                                            
                                                                                                                  
                                                                                                                                                                            
additional_models = [                                                                                                                                                        
    ("Support Vector Regression", SVR(kernel='rbf', C=100, gamma=0.01)),                                                                                                     
    ("AdaBoost Regressor", AdaBoostRegressor(n_estimators=100, learning_rate=0.05, random_state=42)),                                                                        
    ("Extra Trees Regressor", ExtraTreesRegressor(n_estimators=100, random_state=42)),                                                                                       
    ("Ridge with higher alpha", Ridge(alpha=10.0)),                                                                                                                          
    ("Random Forest with deeper trees", RandomForestRegressor(n_estimators=100, max_depth=20, random_state=42)),                                                             
]                                                                                                                                                                            
                                                                                                                                                                            
                                                                                                                                                      
fit_sklearn_models_with_cv_and_dvc(additional_models, X_train, X_test, y_train, y_test, dvc_metadata)
# Out:
# 2026/04/11 15:12:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:11 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:11 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:11 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:12 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:12 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:12 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Support Vector Regression:
#   RMSE: 75913.77
#   MAE: 53340.35
#   R^2: -0.009
#   CV R^2 (mean ± std): -0.065 ± 0.069
#   DVC MD5: f44053333f88a0646819936b37f000ee
# 🏃 View run Support Vector Regression at: http://localhost:5001/#/experiments/1/runs/b1fdf2718ef14cccbb53f457a986e91b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:12:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:15 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:15 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:16 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:16 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# AdaBoost Regressor:
#   RMSE: 34183.02
#   MAE: 23422.21
#   R^2: 0.795
#   CV R^2 (mean ± std): 0.793 ± 0.076
#   DVC MD5: f44053333f88a0646819936b37f000ee
# 🏃 View run AdaBoost Regressor at: http://localhost:5001/#/experiments/1/runs/b9a7937bca7c45bdae67db08ee15006e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:12:17 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:19 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:19 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:20 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:21 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:21 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:22 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:22 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:23 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Extra Trees Regressor:
#   RMSE: 23448.54
#   MAE: 14918.67
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.889 ± 0.042
#   DVC MD5: f44053333f88a0646819936b37f000ee
# 🏃 View run Extra Trees Regressor at: http://localhost:5001/#/experiments/1/runs/c6229c7857fe4538bb8a564df3e4af10
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:12:24 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge with higher alpha:
#   RMSE: 23781.14
#   MAE: 16602.76
#   R^2: 0.901
#   CV R^2 (mean ± std): 0.890 ± 0.028
#   DVC MD5: f44053333f88a0646819936b37f000ee
# 🏃 View run Ridge with higher alpha at: http://localhost:5001/#/experiments/1/runs/2166b8c430ea4c4a90c6d07687c78ee9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/11 15:12:25 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:26 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:26 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:28 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:28 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:29 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:29 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:30 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/11 15:12:30 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/11 15:12:31 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Random Forest with deeper trees:
#   RMSE: 25853.19
#   MAE: 15608.84
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
#   DVC MD5: f44053333f88a0646819936b37f000ee
# 🏃 View run Random Forest with deeper trees at: http://localhost:5001/#/experiments/1/runs/d7fc58f26c4649aa80721b747ac8017d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Manual logging with PyTorch
#
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but we often need low-level control of pure PyTorch.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# <Experiment: artifact_location='/mlflow/artifacts/2', creation_time=1775907838998, experiment_id='2', last_update_time=1775907838998, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation
#
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them.

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model
#
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        required_keys = ['hidden_units', 'dropout', 'batch_size', 'learning_rate', 
                         'log_interval', 'epochs', 'name']
        missing = [key for key in required_keys if key not in config]
        if missing:
            raise ValueError(f"Missing required config keys: {missing}")
        
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def _log_dvc_metadata(self, dvc_file_path: str = 'data/ames_data_2006_2008.parquet.dvc'):
        try:
            dvc_metadata = get_dvc_metadata(dvc_file_path)
            
            mlflow.log_param("data_dvc_md5", dvc_metadata['md5'])
            mlflow.log_param("data_dvc_size", dvc_metadata['size'])
            mlflow.log_param("data_path", dvc_metadata['path'])
            print(f"Logged DVC metadata: {dvc_metadata['md5'][:8]}...")
        except FileNotFoundError:
            print("DVC file not found - skipping metadata logging")
        except Exception as e:
            print(f"Could not log DVC metadata: {e}")

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)
            
            # Log DVC metadata for data versioning
            self._log_dvc_metadata()

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.
#
# ### Configuration
# `base_config` contains **fixed parameters** that stay the same across all experiments:
# - `model_class`: The neural network architecture we're using (HousePriceNet)
# - `random_seed`: For reproducibility (42)
# - `log_interval`: How often to log metrics during training (every 5 epochs)
# - `num_samples`: Dataset size
# - `input_features`: Number of input features
# - `k_folds`: Number of cross-validation folds (5)
#
# `experiment_config` contains **hyperparameters** we want to tune:
# - `name`: Unique identifier for this experiment run
# - `hidden_units`: Size of the hidden layer (128, 256, 512, etc.)
# - `dropout`: Dropout rate for regularization (0.0 to 0.5)
# - `learning_rate`: Step size for gradient descent (0.001 to 0.1)
# - `epochs`: Number of training iterations (50, 100, 150, etc.)
# - `batch_size`: Number of samples per training batch (16, 32, 64, etc.)
#
# If you want you can deliver your own NeuralNetwork model, and just specify in experiment_config: `{"model_class": YourOwnModel}` it will overwrite the our base `HousePriceNet`

# %% [markdown]
# #### 3. Merging configurations
# We use Python's dictionary merge operator `|` to combine them:
# ```python
# training_config = base_config | experiment_config
# ```
#
# This creates a single configuration dictionary with all parameters. The `experiment_config` values override any duplicate keys from `base_config`, allowing us to easily experiment with different hyperparameters while keeping the base setup constant.
#
# Now let's set up our first experiment:

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

experiment_config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | experiment_config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 102278.13, MAE: 81799.64 R^2: -0.450
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 53910.14, MAE: 44721.82 R^2: 0.524
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 25483.16, MAE: 18171.26 R^2: 0.903
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 34607.08, MAE: 25783.52 R^2: 0.790
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 27076.27, MAE: 18438.29 R^2: 0.874
#
# Cross-validation complete. Mean R^2: 0.528 (+/- 0.507)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.528 (+/- 0.507)
#
# Cross-Validation Performance:
#   R^2: 0.861
#   RMSE: 28165.94
#   MAE: 19934.74
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5001/#/experiments/2/runs/56c75bb739654f03b5a594b06ae6d6e8
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# {'rmse': 28165.9375,
#  'mae': 19934.73828125,
#  'r2': 0.8611544966697693,
#  'cv_r2_mean': np.float64(0.5283053040504455),
#  'cv_r2_std': np.float64(0.5069126737420552),
#  'cv_scores': [-0.4495265483856201,
#   0.5236347317695618,
#   0.9032539129257202,
#   0.7903804779052734,
#   0.8737839460372925]}

# %% [markdown]
# ### Exercise 2
#
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# **How to modify configurations:**
#
# You have two approaches:
#
# #### Approach 1: Loop through multiple configurations (Recommended for systematic exploration)
#
# Define a list of experiment configurations and iterate through them. Each configuration dictionary should contain only the hyperparameters you want to tune (name, hidden_units, dropout, learning_rate, epochs, batch_size). The base_config stays the same.
#
# ```python
# base_config = {
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],  # Number of features (181)
#     "num_samples": X_train.shape[0],     # Dataset size (1312)
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# # Define multiple experiments to run
# configs = [
#     {
#         "name": "baseline_128_units",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     {
#         "name": "larger_network_256",
#         "hidden_units": 256,        # Try larger network
#         "dropout": 0.2,             # More dropout for regularization
#         "learning_rate": 0.01,      # Lower learning rate
#         "epochs": 200,
#         "batch_size": 64,
#     },
#     {
#         "name": "high_regularization",
#         "hidden_units": 128,
#         "dropout": 0.3,             # Even more dropout
#         "learning_rate": 0.01,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     # Add 7 more configurations here...
# ]
#
# # Run all experiments
# for experiment_config in configs:
#     training_config = base_config | experiment_config
#
#     trainer = PyTorchTrainer(training_config["model_class"], training_config)
#     results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
#
# #### Approach 2: Manual and incremental (Good for quick iterations)
#
# Run experiments one by one, adjusting hyperparameters based on previous results:
#
# ```python
# # First experiment
# experiment_config = {
#     "name": "experiment_01_baseline",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
# After analyzing results in MLflow, run another experiment
#
# ```
# experiment_config = {
#     "name": "experiment_02_more_dropout",
#     "hidden_units": 128,
#     "dropout": 0.3,  # Increased from 0.1
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
#
# # Continue with more experiments
# ```

# %% [markdown]
# **Tips for hyperparameter tuning:**
# - Start with one change at a time to understand its impact
# - Use meaningful experiment names that describe what you changed
# - Check MLflow UI after each experiment to guide your next choice
# - Look for signs of overfitting: high training performance but poor test performance
# - Watch the training curves in MLflow's "Model metrics" tab

# %%
base_config = {                                                                                                                                                              
    "model_class": HousePriceNet,                                                                                                                                            
    "random_seed": 42,                                                                                                                                                       
    "log_interval": 5,
    "input_features": X_train.shape[1],
    "num_samples": X_train.shape[0],                                                                                                           
    "target_normalized": True,
    "k_folds": 5,                                                                                                                                                            
}                                                                                                                                                                            

# Define multiple experiments to run (approach 1st)                                                                                                                                       
configs = [     
    {
        "name": "baseline_128_units",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "larger_network_256",
        "hidden_units": 256,        # larger network
        "dropout": 0.2,             # more dropout for regularization
        "learning_rate": 0.01,      # lower learning rate
        "epochs": 200,
        "batch_size": 64,
    },
    {
        "name": "high_regularization",
        "hidden_units": 128,                                                                                                                                                 
        "dropout": 0.3,             # even more dropout
        "learning_rate": 0.01,                                                                                                                                               
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "very_high_dropout",
        "hidden_units": 128,
        "dropout": 0.4,             # very high dropout for strong regularization
        "learning_rate": 0.005,     # even lower learning rate
        "epochs": 200,
        "batch_size": 32,
    },
    {
        "name": "small_network_high_drop",
        "hidden_units": 64,         # smaller network                                                                                                                        
        "dropout": 0.3,             # high dropout                                                                                                                           
        "learning_rate": 0.01,                                                                                                                                               
        "epochs": 200,                                                                                                                                                       
        "batch_size": 32,
    },
    {
        "name": "large_batch_regularized",
        "hidden_units": 128,                                                                                                                                                 
        "dropout": 0.25,            # medium-high dropout
        "learning_rate": 0.01,                                                                                                                                               
        "epochs": 150,                                                                                                                                                       
        "batch_size": 64,           # larger batch size
    },                                                                                                                                                                       
    {           
        "name": "very_low_lr",
        "hidden_units": 128,
        "dropout": 0.2,
        "learning_rate": 0.001,     # very low learning rate
        "epochs": 300,              # more epochs
        "batch_size": 32,
    },
    {
        "name": "balanced_config_1",
        "hidden_units": 96,         # medium network
        "dropout": 0.25,                                                                                                                                                     
        "learning_rate": 0.01,
        "epochs": 150,                                                                                                                                                       
        "batch_size": 48,
    },
    {
        "name": "balanced_config_2",
        "hidden_units": 96,
        "dropout": 0.2,
        "learning_rate": 0.005,
        "epochs": 200,
        "batch_size": 48,                                                                                                                                                    
    },                                                                                                                                                                       
    {                                                                                                                                                                        
        "name": "aggressive_regularization",                                                                                                                                 
        "hidden_units": 64,                                                                                                                                                  
        "dropout": 0.35,                                                                                                                                                     
        "learning_rate": 0.005,                                                                                                                                              
        "epochs": 250,                                                                                                                                                       
        "batch_size": 64,
    },                                                                                                                                                                       
]

for experiment_config in configs:
    print(f"\n{'='*60}")
    print(f"Starting Experiment: {experiment_config['name']}")
    print(f"{'='*60}")
    
    training_config = base_config | experiment_config 
    
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# ============================================================
# Starting Experiment: baseline_128_units
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for baseline_128_units...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27108.33, MAE: 18851.00 R^2: 0.898
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 31419.01, MAE: 25953.80 R^2: 0.838
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 45969.81, MAE: 37567.81 R^2: 0.685
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 25474.40, MAE: 17823.35 R^2: 0.886
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 31933.96, MAE: 22745.51 R^2: 0.824
#
# Cross-validation complete. Mean R^2: 0.826 (+/- 0.076)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.826 (+/- 0.076)
#
# Cross-Validation Performance:
#   R^2: 0.784
#   RMSE: 35113.39
#   MAE: 26735.17
# Test Set Performance:
# ==================================================
# FINAL RESULTS for baseline_128_units:
#
# ==================================================
# 🏃 View run baseline_128_units at: http://localhost:5001/#/experiments/2/runs/9b9b5cc18d1348dba34e6e002f0e7f17
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: larger_network_256
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for larger_network_256...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 106503.66, MAE: 78091.95 R^2: -0.572
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 93320.52, MAE: 66774.27 R^2: -0.427
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 51351.83, MAE: 36849.90 R^2: 0.607
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 101663.44, MAE: 56058.82 R^2: -0.809
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 41476.65, MAE: 29603.49 R^2: 0.704
#
# Cross-validation complete. Mean R^2: -0.099 (+/- 0.629)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.099 (+/- 0.629)
#
# Cross-Validation Performance:
#   R^2: 0.553
#   RMSE: 50515.15
#   MAE: 37006.84
# Test Set Performance:
# ==================================================
# FINAL RESULTS for larger_network_256:
#
# ==================================================
# 🏃 View run larger_network_256 at: http://localhost:5001/#/experiments/2/runs/fcfc793537b94d51b4db04655515aa8d
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: high_regularization
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for high_regularization...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 51315.58, MAE: 43028.85 R^2: 0.635
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 35644.25, MAE: 26744.05 R^2: 0.792
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 31168.28, MAE: 21272.65 R^2: 0.855
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 35158.11, MAE: 24304.57 R^2: 0.784
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 37573.58, MAE: 28237.20 R^2: 0.757
#
# Cross-validation complete. Mean R^2: 0.765 (+/- 0.072)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.765 (+/- 0.072)
#
# Cross-Validation Performance:
#   R^2: 0.895
#   RMSE: 24503.94
#   MAE: 16896.02
# Test Set Performance:
# ==================================================
# FINAL RESULTS for high_regularization:
#
# ==================================================
# 🏃 View run high_regularization at: http://localhost:5001/#/experiments/2/runs/f9e5846849764492b9b83fc58ae070c4
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: very_high_dropout
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for very_high_dropout...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27358.71, MAE: 19951.37 R^2: 0.896
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 46028.87, MAE: 37871.04 R^2: 0.653
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 49559.27, MAE: 37558.46 R^2: 0.634
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 28753.02, MAE: 20529.91 R^2: 0.855
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 48357.18, MAE: 37028.55 R^2: 0.597
#
# Cross-validation complete. Mean R^2: 0.727 (+/- 0.123)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.727 (+/- 0.123)
#
# Cross-Validation Performance:
#   R^2: 0.887
#   RMSE: 25418.41
#   MAE: 18515.78
# Test Set Performance:
# ==================================================
# FINAL RESULTS for very_high_dropout:
#
# ==================================================
# 🏃 View run very_high_dropout at: http://localhost:5001/#/experiments/2/runs/a928e3c38f9a4eb590e3e468b026fcce
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: small_network_high_drop
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for small_network_high_drop...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 22862.08, MAE: 16189.80 R^2: 0.928
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 21341.76, MAE: 13957.62 R^2: 0.925
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24503.97, MAE: 16572.12 R^2: 0.911
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 22273.01, MAE: 15229.51 R^2: 0.913
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24537.47, MAE: 16860.16 R^2: 0.896
#
# Cross-validation complete. Mean R^2: 0.915 (+/- 0.011)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.915 (+/- 0.011)
#
# Cross-Validation Performance:
#   R^2: 0.899
#   RMSE: 23983.84
#   MAE: 16825.55
# Test Set Performance:
# ==================================================
# FINAL RESULTS for small_network_high_drop:
#
# ==================================================
# 🏃 View run small_network_high_drop at: http://localhost:5001/#/experiments/2/runs/9c8e06c69e1d4de59e8bd5fb4a68aded
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: large_batch_regularized
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for large_batch_regularized...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 45539.57, MAE: 33127.27 R^2: 0.713
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 41420.13, MAE: 31571.54 R^2: 0.719
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 61909.22, MAE: 46860.36 R^2: 0.429
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 45558.56, MAE: 33369.92 R^2: 0.637
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 41767.68, MAE: 30078.54 R^2: 0.700
#
# Cross-validation complete. Mean R^2: 0.639 (+/- 0.109)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.639 (+/- 0.109)
#
# Cross-Validation Performance:
#   R^2: 0.678
#   RMSE: 42921.07
#   MAE: 29797.65
# Test Set Performance:
# ==================================================
# FINAL RESULTS for large_batch_regularized:
#
# ==================================================
# 🏃 View run large_batch_regularized at: http://localhost:5001/#/experiments/2/runs/53f39b8e7f0d47a1b7ad17207e372476
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: very_low_lr
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for very_low_lr...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 61716.77, MAE: 47229.41 R^2: 0.472
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 51596.10, MAE: 34812.39 R^2: 0.564
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 56730.12, MAE: 43216.71 R^2: 0.521
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 51161.89, MAE: 31206.52 R^2: 0.542
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 39504.16, MAE: 28807.87 R^2: 0.731
#
# Cross-validation complete. Mean R^2: 0.566 (+/- 0.088)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.566 (+/- 0.088)
#
# Cross-Validation Performance:
#   R^2: 0.286
#   RMSE: 63872.35
#   MAE: 48211.07
# Test Set Performance:
# ==================================================
# FINAL RESULTS for very_low_lr:
#
# ==================================================
# 🏃 View run very_low_lr at: http://localhost:5001/#/experiments/2/runs/7676ec740bf44c749e4c4ab13ff3cb94
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: balanced_config_1
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for balanced_config_1...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 92708.56, MAE: 84545.30 R^2: -0.191
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 70317.38, MAE: 47437.39 R^2: 0.190
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 43745.80, MAE: 31558.75 R^2: 0.715
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 52974.60, MAE: 40436.97 R^2: 0.509
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 52587.30, MAE: 41102.46 R^2: 0.524
#
# Cross-validation complete. Mean R^2: 0.349 (+/- 0.318)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.349 (+/- 0.318)
#
# Cross-Validation Performance:
#   R^2: 0.815
#   RMSE: 32472.01
#   MAE: 23357.12
# Test Set Performance:
# ==================================================
# FINAL RESULTS for balanced_config_1:
#
# ==================================================
# 🏃 View run balanced_config_1 at: http://localhost:5001/#/experiments/2/runs/fc564e830af64a00ac1714f3d263b8db
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: balanced_config_2
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for balanced_config_2...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 89979.17, MAE: 62832.76 R^2: -0.122
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44139.04, MAE: 36884.91 R^2: 0.681
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 39987.06, MAE: 29514.76 R^2: 0.762
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 70065.22, MAE: 48394.17 R^2: 0.141
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 50457.88, MAE: 41483.17 R^2: 0.562
#
# Cross-validation complete. Mean R^2: 0.405 (+/- 0.339)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.405 (+/- 0.339)
#
# Cross-Validation Performance:
#   R^2: 0.506
#   RMSE: 53101.65
#   MAE: 42183.70
# Test Set Performance:
# ==================================================
# FINAL RESULTS for balanced_config_2:
#
# ==================================================
# 🏃 View run balanced_config_2 at: http://localhost:5001/#/experiments/2/runs/3e7cec7966284c989371238a8d4ab072
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# ============================================================
# Starting Experiment: aggressive_regularization
# ============================================================
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for aggressive_regularization...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 34379.79, MAE: 24758.38 R^2: 0.836
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 41238.84, MAE: 34154.84 R^2: 0.721
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 52379.36, MAE: 40614.73 R^2: 0.591
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 45435.91, MAE: 35903.98 R^2: 0.639
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 29827.24, MAE: 20740.08 R^2: 0.847
#
# Cross-validation complete. Mean R^2: 0.727 (+/- 0.103)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.727 (+/- 0.103)
#
# Cross-Validation Performance:
#   R^2: 0.781
#   RMSE: 35341.21
#   MAE: 26514.63
# Test Set Performance:
# ==================================================
# FINAL RESULTS for aggressive_regularization:
#
# ==================================================
# 🏃 View run aggressive_regularization at: http://localhost:5001/#/experiments/2/runs/b96204f5e637488f9134492074ad8734
# 🧪 View experiment at: http://localhost:5001/#/experiments/2

# %% [markdown]
# **Comment on what changes impacted the model performance the most, and what changes disrupted the training process.**
#
# Co najbardziej poprawiło wyniki:<br>
# Największy pozytywny wpływ miało zmniejszenie rozmiaru sieci w połączeniu z silną regularyzacją. Eksperyment small_network_high_drop (tylko 64 neurony w warstwie ukrytej i wysoki dropout 0.3) osiągnął zdecydowanie najlepsze rezultaty: bardzo wysoki i stabilny wynik walidacji krzyżowej (CV $R^2$: 0.915) oraz świetny wynik na zbiorze testowym ($R^2$: 0.899). Udowadnia to, że przy tak małym zbiorze danych (1312 próbek) i dużej liczbie cech (181), prostszy model znacznie lepiej generalizuje wiedzę i unika przeuczenia.
#
# Co zakłóciło proces uczenia:<br>
# - Zbyt duża pojemność sieci (overfitting): Eksperyment larger_network_256 (zwiększenie do 256 neuronów) zakończył się spodziewanymi, fatalnymi wynikami. Wynik CV $R^2$ spadł poniżej zera (-0.099). Model zaczął zapamiętywać szum zamiast uczyć się wzorców.
# - Zbyt niski współczynnik uczenia (underfitting): W eksperymencie very_low_lr obniżenie learning rate do 0.001 sprawiło, że model nie był w stanie zbiec do optymalnego rozwiązania, mimo zwiększenia liczby epok do 300. Wynik na zbiorze testowym spadł ($R^2$: 0.286).
# - Zbyt duży rozmiar danych w partii (batch size): Eksperymenty używające batch_size: 64 (np. large_batch_regularized) radziły sobie zauważalnie gorzej niż te z batchem 32. Przy tak małym zbiorze danych większy batch size prawdopodobnie prowadził do gorszej generalizacji i utykania w lokalnych minimach.
#
#
#
# **Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.**
#
# Porównanie: Model sklearn, a w szczególności Gradient Boosting, jest dokładniejszy i stabilniejszy niż PyTorch. Niestety jedyną metryką porównawczą jest R2, ale zdecydowanie widać, że model scikit-learn wyjaśnia znacznie więcej wariancji zbioru uczącego niż ten z PyTorcha.
# ![image.png](attachment:image.png)
#
# Przeuczenie (overfitting) w PyTorch występuje w pierwszym eksperymencie PyTorch (albo mam wyjątkowo "szczęśliwy" podział na foldy przy CV).
# Widać wyraźne oznaki przeuczenia i dużej niestabilności. Wskazują na to następujące sygnały:
# - Skrajne wahania w walidacji krzyżowej (CV): Wyniki $R^2$ skaczą od -0.450 do 0.903 (odchylenie standardowe to aż $\pm 0.507$). Model jest bardzo wrażliwy na to, który batch danych jest użyty do uczenia.
# - Ujemny wynik $R^2$ (Fold 1): Wynik -0.450 oznacza, że model radzi sobie gorzej niż przewidywanie zwykłej średniej. To klasyczny objaw silnego przeuczenia – model "zapamiętał" szum z danych treningowych i zupełnie nie radzi sobie z nowymi danymi.
# - Duża rozbieżność wyników: Ostateczny wynik testowy (0.861) jest nieproporcjonalnie wyższy od średniej z CV (0.528).
#
# Porównujac metryki błędu odległości typu mse, rmse równiez mozna stwierdzić, ze występuje przeuczenie. Bardzo małe błędy na zbiorze treningowym `final_train_mse` i relacyjnie duze błędy w zbiorach walidacyjnych

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.
